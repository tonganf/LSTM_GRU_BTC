# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import torch
from torch import nn
from sklearn.model_selection import train_test_split

# %%
BTC = yf.Ticker('BTC-USD')
BTC.info
# Out:
# {'name': 'Bitcoin',
#  'startDate': 1278979200,
#  'description': 'Bitcoin (BTC) is a cryptocurrency launched in 2010. Users are able to generate BTC through the process of mining. Bitcoin has a current supply of 19,685,043. The last known price of Bitcoin is 63,358.32037414 USD and is up 0.05 over the last 24 hours. It is currently trading on 11008 active market(s) with $38,666,232,360.59 traded over the last 24 hours. More information can be found at https://bitcoin.org/.',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 61281.86,
#  'open': 61281.86,
#  'dayLow': 61043.3,
#  'dayHigh': 62121.496,
#  'regularMarketPreviousClose': 61281.86,
#  'regularMarketOpen': 61281.86,
#  'regularMarketDayLow': 61043.3,
#  'regularMarketDayHigh': 62121.496,
#  'volume': 42461388800,
#  'regularMarketVolume': 42461388800,
#  'averageVolume': 35420637677,
#  'averageVolume10days': 39589205153,
#  'averageDailyVolume10Day': 39589205153,
#  'marketCap': 1220062740480,
#  'fiftyTwoWeekLow': 24797.168,
#  'fiftyTwoWeekHigh': 73750.07,
#  'fiftyDayAverage': 67214.24,
#  'twoHundredDayAverage': 46615.254,
#  'currency': 'USD',
#  'fromCurrency': 'BTC',
#  'toCurrency': 'USD=X',
#  'lastMarket': 'CoinMarketCap',
#  'coinMarketCapLink': 'https://coinmarketcap.com/currencies/bitcoin',
#  'volume24Hr': 42461388800,
#  'volumeAllCurrencies': 42461388800,
#  'circulatingSupply': 19685776,
#  'exchange': 'CCC',
#  'quoteType': 'CRYPTOCURRENCY',
#  'symbol': 'BTC-USD',
#  'underlyingSymbol': 'BTC-USD',
#  'shortName': 'Bitcoin USD',
#  'longName': 'Bitcoin USD',
#  'firstTradeDateEpochUtc': 1410912000,
#  'timeZoneFullName': 'UTC',
#  'timeZoneShortName': 'UTC',
#  'uuid': '74397779-1589-3270-8c45-b7f1a7345b3a',
#  'messageBoardId': 'finmb_BTC_CCC',
#  'trailingPegRatio': None}

# %%
print('Name: ', BTC.info['longName'])
# Out:
# Name:  Bitcoin USD

# %%
df = BTC.history(period='1d', start="2013-03-15", end="2024-03-21")

# %%
df.head(5)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00  21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00  34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00  37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00  36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00  26580100        0.0           0.0

# %% [markdown]
# ## Cleaning data

# %%
df = df.iloc[:,:-2]
df.tail(5)
# Out:
#                                    Open          High           Low  \
# Date
# 2024-03-16 00:00:00+00:00  69392.484375  70046.273438  64801.394531
# 2024-03-17 00:00:00+00:00  65316.343750  68845.718750  64545.316406
# 2024-03-18 00:00:00+00:00  68371.304688  68897.132812  66594.226562
# 2024-03-19 00:00:00+00:00  67556.132812  68106.929688  61536.179688
# 2024-03-20 00:00:00+00:00  61930.156250  68115.257812  60807.785156
#
#                                   Close       Volume
# Date
# 2024-03-16 00:00:00+00:00  65315.117188  46842198371
# 2024-03-17 00:00:00+00:00  68390.625000  44716864318
# 2024-03-18 00:00:00+00:00  67548.593750  49261579492
# 2024-03-19 00:00:00+00:00  61912.773438  74215844794
# 2024-03-20 00:00:00+00:00  67913.671875  66792634382

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3473 entries, 2014-09-17 00:00:00+00:00 to 2024-03-20 00:00:00+00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3473 non-null   float64
#  1   High    3473 non-null   float64
#  2   Low     3473 non-null   float64
#  3   Close   3473 non-null   float64
#  4   Volume  3473 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 162.8 KB

# %%
plt.figure(figsize=(18,6))
plt.plot(df.index, df['Close'], lw=2)
plt.xlabel("Date", fontsize=16)
plt.ylabel("Close price", fontsize=16)
plt.title("Giá BTC", fontsize=16);

# %% [markdown]
# # Chia dữ liệu Train_test

# %%
y = df['Close']
y = y.values.reshape(-1, 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler = scaler.fit(y)
y = scaler.transform(y)

# %%
# generate the input and output sequences
n_lookback = 60 # length of input sequences (lookback period)
n_forecast = 120 # length of the sequences (forecast period)

X = []
Y = []

for i in range(n_lookback, len(y) - n_forecast + 1):
    X.append(y[i - n_lookback : i])
    Y.append(y[i : i + n_forecast])

X = np.array(X)
Y = np.array(Y)

# %%
from torch.utils.data import DataLoader, TensorDataset

X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32).squeeze(-1)

# Chia tập dữ liệu
X_train, X_test, Y_train, Y_test = train_test_split(X_tensor, Y_tensor, test_size=0.2, random_state=42)

# Tạo DataLoaders cho PyTorch
train_dataset = TensorDataset(X_train, Y_train)
test_dataset = TensorDataset(X_test, Y_test)

train_loader = DataLoader(dataset=train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## Tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
# fit the model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(n_lookback, 1)))
model.add(LSTM(units=50))
model.add(Dense(n_forecast))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X, Y, epochs=100, batch_size=32, verbose=0)

# %%
X_ = y[-n_lookback:]  #last available input sequence
X_ = X_.reshape(1, n_lookback, 1)
Y_ = model.predict(X_).reshape(-1, 1)
Y_ = scaler.inverse_transform(Y_)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# ## Pytorch

# %%
import torch
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(device)
        
        out, (hn, cn) = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
def training_loop(model, train_loader, test_loader, num_epochs):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = torch.nn.MSELoss()

    all_train_losses = []  
    all_test_losses = []  
    best_accuracy = 0.0 
    best_model_state_dict = None  # Lưu trữ tham số của mô hình tốt nhất
    
    for epoch in range(num_epochs):
        model.train()
        train_losses = []
        for X_batch, Y_batch in train_loader:
            X_batch, Y_batch = X_batch.to(device), Y_batch.to(device)
            optimizer.zero_grad()
            Y_pred = model(X_batch)
            loss = criterion(Y_pred, Y_batch)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        # Đánh giá sau mỗi epoch
        model.eval()
        test_losses = []
        test_accuracy = 0.0  
        with torch.no_grad():
            for X_batch, Y_batch in test_loader:
                X_batch, Y_batch = X_batch.to(device), Y_batch.to(device)
                Y_pred = model(X_batch)
                loss = criterion(Y_pred, Y_batch)
                test_losses.append(loss.item())
                test_accuracy += loss.item()
                
        # Cập nhật mô hình tốt nhất nếu độ chính xác hiện tại tốt hơn
        if test_accuracy > best_accuracy:
            best_accuracy = test_accuracy
            best_model_state_dict = model.state_dict()  # Lưu trữ tham số mô hình
        
        train_loss_avg = np.mean(train_losses)
        test_loss_avg = np.mean(test_losses)
        
        # Lưu trữ loss trung bình của mỗi epoch
        all_train_losses.append(train_loss_avg)
        all_test_losses.append(test_loss_avg)

        print('Epoch[{}/{}] | loss train:{:.6f}, test:{:.6f}'
              .format(epoch+1, num_epochs, train_loss_avg, test_loss_avg))

    return all_train_losses, all_test_losses, best_model_state_dict

# %%
model_lstm = LSTM(1, 50, 3, 120)
model_lstm.to(device)
# Out:
# LSTM(
#   (lstm): LSTM(1, 50, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=50, out_features=120, bias=True)
# )

# %%
train_losses, test_losses, best_model = training_loop(model_lstm, train_loader, test_loader, num_epochs=200)

plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch[1/200] | loss train:0.040714, test:0.010413
# Epoch[2/200] | loss train:0.009573, test:0.007895
# Epoch[3/200] | loss train:0.009209, test:0.007274
# Epoch[4/200] | loss train:0.008780, test:0.007117
# Epoch[5/200] | loss train:0.008422, test:0.007007
# Epoch[6/200] | loss train:0.008462, test:0.007294
# Epoch[7/200] | loss train:0.008542, test:0.006660
# Epoch[8/200] | loss train:0.008145, test:0.007853
# Epoch[9/200] | loss train:0.008368, test:0.006740
# Epoch[10/200] | loss train:0.007889, test:0.006454
# Epoch[11/200] | loss train:0.007926, test:0.006434
# Epoch[12/200] | loss train:0.007895, test:0.006992
# Epoch[13/200] | loss train:0.007799, test:0.006760
# Epoch[14/200] | loss train:0.007816, test:0.006336
# Epoch[15/200] | loss train:0.007810, test:0.006866
# Epoch[16/200] | loss train:0.007976, test:0.006714
# Epoch[17/200] | loss train:0.009041, test:0.007439
# Epoch[18/200] | loss train:0.008248, test:0.006454
# Epoch[19/200] | loss train:0.007939, test:0.006358
# Epoch[20/200] | loss train:0.007729, test:0.006446
# Epoch[21/200] | loss train:0.007707, test:0.006723
# Epoch[22/200] | loss train:0.007859, test:0.006415
# Epoch[23/200] | loss train:0.007854, test:0.006430
# Epoch[24/200] | loss train:0.007878, test:0.006349
# Epoch[25/200] | loss train:0.007611, test:0.006493
# Epoch[26/200] | loss train:0.007797, test:0.006882
# Epoch[27/200] | loss train:0.007907, test:0.006416
# Epoch[28/200] | loss train:0.007698, test:0.006335
# Epoch[29/200] | loss train:0.007560, test:0.006179
# Epoch[30/200] | loss train:0.007546, test:0.006466
# Epoch[31/200] | loss train:0.007563, test:0.007476
# Epoch[32/200] | loss train:0.007646, test:0.006305
# Epoch[33/200] | loss train:0.007625, test:0.006487
# Epoch[34/200] | loss train:0.007219, test:0.005992
# Epoch[35/200] | loss train:0.008792, test:0.009832
# Epoch[36/200] | loss train:0.009568, test:0.006250
# Epoch[37/200] | loss train:0.007698, test:0.006312
# Epoch[38/200] | loss train:0.007431, test:0.006091
# Epoch[39/200] | loss train:0.007352, test:0.006435
# Epoch[40/200] | loss train:0.007522, test:0.006194
# Epoch[41/200] | loss train:0.007341, test:0.005932
# Epoch[42/200] | loss train:0.007092, test:0.006516
# Epoch[43/200] | loss train:0.006833, test:0.006031
# Epoch[44/200] | loss train:0.007120, test:0.005835
# Epoch[45/200] | loss train:0.007046, test:0.005732
# Epoch[46/200] | loss train:0.006920, test:0.005491
# Epoch[47/200] | loss train:0.006981, test:0.005779
# Epoch[48/200] | loss train:0.006843, test:0.005399
# Epoch[49/200] | loss train:0.007028, test:0.005411
# Epoch[50/200] | loss train:0.006510, test:0.005697
# Epoch[51/200] | loss train:0.007286, test:0.005500
# Epoch[52/200] | loss train:0.006492, test:0.005189
# Epoch[53/200] | loss train:0.006534, test:0.004840
# Epoch[54/200] | loss train:0.006326, test:0.008599
# Epoch[55/200] | loss train:0.009673, test:0.005766
# Epoch[56/200] | loss train:0.006605, test:0.005609
# Epoch[57/200] | loss train:0.006681, test:0.005313
# Epoch[58/200] | loss train:0.006493, test:0.006271
# Epoch[59/200] | loss train:0.006429, test:0.005255
# Epoch[60/200] | loss train:0.006597, test:0.005606
# Epoch[61/200] | loss train:0.006672, test:0.005221
# Epoch[62/200] | loss train:0.006589, test:0.006348
# Epoch[63/200] | loss train:0.006396, test:0.005222
# Epoch[64/200] | loss train:0.006136, test:0.005169
# Epoch[65/200] | loss train:0.006080, test:0.005137
# Epoch[66/200] | loss train:0.006421, test:0.006187
# Epoch[67/200] | loss train:0.006614, test:0.005553
# Epoch[68/200] | loss train:0.006317, test:0.006151
# Epoch[69/200] | loss train:0.007522, test:0.006081
# Epoch[70/200] | loss train:0.007007, test:0.005622
# Epoch[71/200] | loss train:0.006542, test:0.004420
# Epoch[72/200] | loss train:0.005647, test:0.005320
# Epoch[73/200] | loss train:0.005354, test:0.004215
# Epoch[74/200] | loss train:0.004556, test:0.004559
# Epoch[75/200] | loss train:0.004113, test:0.005445
# Epoch[76/200] | loss train:0.004073, test:0.003856
# Epoch[77/200] | loss train:0.004132, test:0.003682
# Epoch[78/200] | loss train:0.003691, test:0.003685
# Epoch[79/200] | loss train:0.003907, test:0.003212
# Epoch[80/200] | loss train:0.003187, test:0.004790
# Epoch[81/200] | loss train:0.003389, test:0.003544
# Epoch[82/200] | loss train:0.006011, test:0.005085
# Epoch[83/200] | loss train:0.005773, test:0.004990
# Epoch[84/200] | loss train:0.004806, test:0.004532
# Epoch[85/200] | loss train:0.004856, test:0.004036
# Epoch[86/200] | loss train:0.004361, test:0.003918
# Epoch[87/200] | loss train:0.004898, test:0.004287
# Epoch[88/200] | loss train:0.004345, test:0.003767
# Epoch[89/200] | loss train:0.004448, test:0.003748
# Epoch[90/200] | loss train:0.004070, test:0.003824
# Epoch[91/200] | loss train:0.003974, test:0.003635
# Epoch[92/200] | loss train:0.003757, test:0.003542
# Epoch[93/200] | loss train:0.003748, test:0.003488
# Epoch[94/200] | loss train:0.003346, test:0.003159
# Epoch[95/200] | loss train:0.003361, test:0.005134
# Epoch[96/200] | loss train:0.003240, test:0.003233
# Epoch[97/200] | loss train:0.003004, test:0.005520
# Epoch[98/200] | loss train:0.004165, test:0.003318
# Epoch[99/200] | loss train:0.003197, test:0.004036
# Epoch[100/200] | loss train:0.004386, test:0.003292
# Epoch[101/200] | loss train:0.003202, test:0.003491
# Epoch[102/200] | loss train:0.003136, test:0.002840
# Epoch[103/200] | loss train:0.002905, test:0.002724
# Epoch[104/200] | loss train:0.003008, test:0.004299
# Epoch[105/200] | loss train:0.002873, test:0.002728
# Epoch[106/200] | loss train:0.002692, test:0.002749
# Epoch[107/200] | loss train:0.006741, test:0.006625
# Epoch[108/200] | loss train:0.006823, test:0.005054
# Epoch[109/200] | loss train:0.011192, test:0.006256
# Epoch[110/200] | loss train:0.006895, test:0.005481
# Epoch[111/200] | loss train:0.006368, test:0.006141
# Epoch[112/200] | loss train:0.006474, test:0.004876
# Epoch[113/200] | loss train:0.005535, test:0.004673
# Epoch[114/200] | loss train:0.005295, test:0.005231
# Epoch[115/200] | loss train:0.005080, test:0.004234
# Epoch[116/200] | loss train:0.004847, test:0.004095
# Epoch[117/200] | loss train:0.004615, test:0.003909
# Epoch[118/200] | loss train:0.004456, test:0.004596
# Epoch[119/200] | loss train:0.004815, test:0.003783
# Epoch[120/200] | loss train:0.004776, test:0.004557
# Epoch[121/200] | loss train:0.005495, test:0.003723
# Epoch[122/200] | loss train:0.005263, test:0.005568
# Epoch[123/200] | loss train:0.005284, test:0.004200
# Epoch[124/200] | loss train:0.004526, test:0.003879
# Epoch[125/200] | loss train:0.004151, test:0.003742
# Epoch[126/200] | loss train:0.004367, test:0.004321
# Epoch[127/200] | loss train:0.004621, test:0.005092
# Epoch[128/200] | loss train:0.003905, test:0.003269
# Epoch[129/200] | loss train:0.003355, test:0.003339
# Epoch[130/200] | loss train:0.003411, test:0.003049
# Epoch[131/200] | loss train:0.003122, test:0.003070
# Epoch[132/200] | loss train:0.003210, test:0.003059
# Epoch[133/200] | loss train:0.002871, test:0.002911
# Epoch[134/200] | loss train:0.002826, test:0.002601
# Epoch[135/200] | loss train:0.002628, test:0.002576
# Epoch[136/200] | loss train:0.003050, test:0.004618
# Epoch[137/200] | loss train:0.003182, test:0.003046
# Epoch[138/200] | loss train:0.002588, test:0.002757
# Epoch[139/200] | loss train:0.002754, test:0.002530
# Epoch[140/200] | loss train:0.002530, test:0.002774
# Epoch[141/200] | loss train:0.002466, test:0.002521
# Epoch[142/200] | loss train:0.003058, test:0.002716
# Epoch[143/200] | loss train:0.003306, test:0.002428
# Epoch[144/200] | loss train:0.002510, test:0.002333
# Epoch[145/200] | loss train:0.002231, test:0.002565
# Epoch[146/200] | loss train:0.002326, test:0.002509
# Epoch[147/200] | loss train:0.002491, test:0.002536
# Epoch[148/200] | loss train:0.002912, test:0.002787
# Epoch[149/200] | loss train:0.002394, test:0.002254
# Epoch[150/200] | loss train:0.002284, test:0.002016
# Epoch[151/200] | loss train:0.001803, test:0.001754
# Epoch[152/200] | loss train:0.001839, test:0.002727
# Epoch[153/200] | loss train:0.002208, test:0.001850
# Epoch[154/200] | loss train:0.003047, test:0.004396
# Epoch[155/200] | loss train:0.003442, test:0.002705
# Epoch[156/200] | loss train:0.002628, test:0.002603
# Epoch[157/200] | loss train:0.002546, test:0.003458
# Epoch[158/200] | loss train:0.002463, test:0.002098
# Epoch[159/200] | loss train:0.001970, test:0.001928
# Epoch[160/200] | loss train:0.001989, test:0.003458
# Epoch[161/200] | loss train:0.004554, test:0.004430
# Epoch[162/200] | loss train:0.002471, test:0.001880
# Epoch[163/200] | loss train:0.002054, test:0.001724
# Epoch[164/200] | loss train:0.001883, test:0.002651
# Epoch[165/200] | loss train:0.002634, test:0.001607
# Epoch[166/200] | loss train:0.001676, test:0.001596
# Epoch[167/200] | loss train:0.001839, test:0.001703
# Epoch[168/200] | loss train:0.001523, test:0.001493
# Epoch[169/200] | loss train:0.001500, test:0.001658
# Epoch[170/200] | loss train:0.002596, test:0.002146
# Epoch[171/200] | loss train:0.001686, test:0.001565
# Epoch[172/200] | loss train:0.001662, test:0.001706
# Epoch[173/200] | loss train:0.001475, test:0.001597
# Epoch[174/200] | loss train:0.001590, test:0.001975
# Epoch[175/200] | loss train:0.001520, test:0.001398
# Epoch[176/200] | loss train:0.002538, test:0.001697
# Epoch[177/200] | loss train:0.001517, test:0.001487
# Epoch[178/200] | loss train:0.001461, test:0.001401
# Epoch[179/200] | loss train:0.003439, test:0.002750
# Epoch[180/200] | loss train:0.001935, test:0.001613
# Epoch[181/200] | loss train:0.001449, test:0.001302
# Epoch[182/200] | loss train:0.002474, test:0.002239
# Epoch[183/200] | loss train:0.001778, test:0.001568
# Epoch[184/200] | loss train:0.001365, test:0.001981
# Epoch[185/200] | loss train:0.001392, test:0.001191
# Epoch[186/200] | loss train:0.001408, test:0.001273
# Epoch[187/200] | loss train:0.001262, test:0.001239
# Epoch[188/200] | loss train:0.003744, test:0.004374
# Epoch[189/200] | loss train:0.005280, test:0.004906
# Epoch[190/200] | loss train:0.003178, test:0.002532
# Epoch[191/200] | loss train:0.002278, test:0.002571
# Epoch[192/200] | loss train:0.002685, test:0.002815
# Epoch[193/200] | loss train:0.002164, test:0.001683
# Epoch[194/200] | loss train:0.001901, test:0.001609
# Epoch[195/200] | loss train:0.001814, test:0.002104
# Epoch[196/200] | loss train:0.001863, test:0.001693
# Epoch[197/200] | loss train:0.004724, test:0.003720
# Epoch[198/200] | loss train:0.003893, test:0.002584
# Epoch[199/200] | loss train:0.003058, test:0.002267
# Epoch[200/200] | loss train:0.002860, test:0.002511

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Test loss')
plt.xlabel('Epochs', color='white')
plt.xticks(color='white')  # Change tick color to 'green'
plt.ylabel('Y-axis', color='white')
plt.ylabel('Loss')
plt.yticks(color='white')  # Change tick color to 'green'
plt.title("Loss_train_test(1,50,5,120)", color='white')
plt.legend()
plt.savefig('loss(1,50,3,120).png', dpi=300, bbox_inches='tight', transparent=True);
plt.show()

# %% [markdown]
# ### Predict model

# %%
model_lstm = LSTM(1, 50, 3, 120)
model_lstm.to(device)
model_lstm.load_state_dict(best_model)
# Out:
# <All keys matched successfully>

# %%
y_predict = torch.tensor(y[-60:], dtype=torch.float32).unsqueeze(0)
y_predict = model_lstm(y_predict.to(device))
y_predict = y_predict.to('cpu').detach().numpy().reshape(-1, 1)
y_predict = scaler.inverse_transform(y_predict)

# %% [markdown]
# #  Create Table
# Tạo bảng chứa kết quả dự đoán của sequence n_forecast theo date của sequence

# %%
def creat_dataframe(data, y_pre):
    df_past = data.reset_index().rename(columns={'Close': 'Price'})
    df_past['Date'] = pd.to_datetime(df_past['Date'])

    # dữ liệu tương lai
    df_future = pd.DataFrame({
        'Date': pd.date_range(start=df_past['Date'].iloc[-1] + pd.Timedelta(days=1), periods=n_forecast),
        'Price': y_pre.flatten()
    })

    results = pd.concat([df_past, df_future], ignore_index=True)
    results['Price'] = results['Price'].astype(float)
    return results

# %% [markdown]
# **Tensorflow**

# %%
data_tensor = create_dataframe(df['Close'], Y_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data_tensor = create_dataframe(df['Close'], Y_)
#
# NameError: name 'create_dataframe' is not defined

# %%
data_tensor[data_tensor['Date'] > '2024-03-01'].plot(x='Date', y = 'Price', lw=2)
plt.ylabel('USD')
plt.title('Giá BTC từ 4-8/2024')
plt.savefig('lstm(1,50,3,120).png', dpi=300, bbox_inches='tight', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data_tensor[data_tensor['Date'] > '2024-03-01'].plot(x='Date', y = 'Price', lw=2)
#       2 plt.ylabel('USD')
#       3 plt.title('Giá BTC từ 4-8/2024')
#
# NameError: name 'data_tensor' is not defined

# %%
data_tensor.plot(x='Date', y='Price')
plt.ylabel('USD')
plt.title('Giá BTC từ 2013 đến 2024-08');

# %% [markdown]
# **Pytorch**

# %%
data_pytorch = creat_dataframe(df['Close'], y_predict)

# %%
data_pytorch[data_pytorch['Date'] > '2024-03-01'].plot(x='Date', y = 'Price', lw=2)
plt.xlabel("Date", color='white')
plt.xticks(color='white')  # Change tick color to 'green'
plt.ylabel('Loss', color = 'white')
plt.yticks(color='white')  # Change tick color to 'green'
plt.title("Giá BTC từ 4-8/2024(1,50,5,120)", color='white')
plt.ylabel('USD')
plt.savefig('lstm(1,50,3,120).png', dpi=300, bbox_inches='tight', transparent=True)

# %%
data_pytorch.plot(x='Date', y='Price')
plt.xlabel("Date", color='white')
plt.xticks(color='white')  # Change tick color to 'green'
plt.ylabel('Loss', color = 'white')
plt.yticks(color='white')  # Change tick color to 'green'
plt.title("Giá BTC từ 4-8/2024(1,50,5,120)", color='white')
plt.ylabel('USD')
plt.savefig('all_lstm(1,50,3,120).png', dpi=300, bbox_inches='tight', transparent=True);

# %% [markdown]
# # GRU

# %%
class GRU(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(GRU, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.gru = nn.GRU(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_().to(device)
        out, (hn) = self.gru(x, (h0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model_gru = GRU(1, 50, 5, 120)
model_gru.to(device)
# Out:
# GRU(
#   (gru): GRU(1, 50, num_layers=5, batch_first=True)
#   (fc): Linear(in_features=50, out_features=120, bias=True)
# )

# %%
train_losses, test_losses, best_model = training_loop(model_gru, train_loader, test_loader, num_epochs=200)

plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch[1/200] | loss train:0.028142, test:0.008004
# Epoch[2/200] | loss train:0.009219, test:0.008600
# Epoch[3/200] | loss train:0.008920, test:0.007397
# Epoch[4/200] | loss train:0.008430, test:0.008052
# Epoch[5/200] | loss train:0.008234, test:0.006676
# Epoch[6/200] | loss train:0.007786, test:0.007200
# Epoch[7/200] | loss train:0.007780, test:0.007412
# Epoch[8/200] | loss train:0.007702, test:0.006001
# Epoch[9/200] | loss train:0.007196, test:0.005665
# Epoch[10/200] | loss train:0.007156, test:0.006029
# Epoch[11/200] | loss train:0.007240, test:0.005409
# Epoch[12/200] | loss train:0.006735, test:0.005536
# Epoch[13/200] | loss train:0.006981, test:0.005380
# Epoch[14/200] | loss train:0.006992, test:0.005296
# Epoch[15/200] | loss train:0.006595, test:0.005036
# Epoch[16/200] | loss train:0.006276, test:0.004990
# Epoch[17/200] | loss train:0.006247, test:0.004772
# Epoch[18/200] | loss train:0.006259, test:0.004530
# Epoch[19/200] | loss train:0.006155, test:0.004432
# Epoch[20/200] | loss train:0.006158, test:0.005821
# Epoch[21/200] | loss train:0.005749, test:0.005083
# Epoch[22/200] | loss train:0.005602, test:0.004117
# Epoch[23/200] | loss train:0.005279, test:0.004021
# Epoch[24/200] | loss train:0.005659, test:0.004148
# Epoch[25/200] | loss train:0.004963, test:0.003852
# Epoch[26/200] | loss train:0.004960, test:0.005943
# Epoch[27/200] | loss train:0.006027, test:0.005098
# Epoch[28/200] | loss train:0.005423, test:0.005138
# Epoch[29/200] | loss train:0.004979, test:0.004110
# Epoch[30/200] | loss train:0.004836, test:0.004246
# Epoch[31/200] | loss train:0.004191, test:0.003552
# Epoch[32/200] | loss train:0.003968, test:0.005249
# Epoch[33/200] | loss train:0.004109, test:0.003580
# Epoch[34/200] | loss train:0.003975, test:0.003417
# Epoch[35/200] | loss train:0.003844, test:0.003657
# Epoch[36/200] | loss train:0.004102, test:0.003587
# Epoch[37/200] | loss train:0.003527, test:0.002747
# Epoch[38/200] | loss train:0.003122, test:0.003066
# Epoch[39/200] | loss train:0.003153, test:0.003149
# Epoch[40/200] | loss train:0.002993, test:0.002364
# Epoch[41/200] | loss train:0.002758, test:0.003178
# Epoch[42/200] | loss train:0.002770, test:0.003264
# Epoch[43/200] | loss train:0.002625, test:0.002387
# Epoch[44/200] | loss train:0.002458, test:0.003386
# Epoch[45/200] | loss train:0.002506, test:0.002264
# Epoch[46/200] | loss train:0.002229, test:0.002075
# Epoch[47/200] | loss train:0.002481, test:0.002917
# Epoch[48/200] | loss train:0.002189, test:0.001801
# Epoch[49/200] | loss train:0.002799, test:0.002280
# Epoch[50/200] | loss train:0.002378, test:0.001942
# Epoch[51/200] | loss train:0.002415, test:0.001872
# Epoch[52/200] | loss train:0.002007, test:0.001860
# Epoch[53/200] | loss train:0.001737, test:0.001639
# Epoch[54/200] | loss train:0.001810, test:0.001499
# Epoch[55/200] | loss train:0.002144, test:0.003075
# Epoch[56/200] | loss train:0.001939, test:0.002316
# Epoch[57/200] | loss train:0.003074, test:0.004504
# Epoch[58/200] | loss train:0.002601, test:0.002001
# Epoch[59/200] | loss train:0.001632, test:0.001546
# Epoch[60/200] | loss train:0.001642, test:0.002257
# Epoch[61/200] | loss train:0.001672, test:0.001520
# Epoch[62/200] | loss train:0.001476, test:0.001568
# Epoch[63/200] | loss train:0.001616, test:0.003840
# Epoch[64/200] | loss train:0.003837, test:0.002067
# Epoch[65/200] | loss train:0.001914, test:0.001658
# Epoch[66/200] | loss train:0.001563, test:0.001534
# Epoch[67/200] | loss train:0.001284, test:0.001253
# Epoch[68/200] | loss train:0.001247, test:0.001294
# Epoch[69/200] | loss train:0.001231, test:0.001230
# Epoch[70/200] | loss train:0.001291, test:0.001283
# Epoch[71/200] | loss train:0.001964, test:0.002043
# Epoch[72/200] | loss train:0.001466, test:0.001188
# Epoch[73/200] | loss train:0.001137, test:0.001183
# Epoch[74/200] | loss train:0.001053, test:0.001076
# Epoch[75/200] | loss train:0.001058, test:0.001114
# Epoch[76/200] | loss train:0.001033, test:0.001067
# Epoch[77/200] | loss train:0.000958, test:0.001036
# Epoch[78/200] | loss train:0.000986, test:0.001081
# Epoch[79/200] | loss train:0.000980, test:0.001026
# Epoch[80/200] | loss train:0.000937, test:0.001008
# Epoch[81/200] | loss train:0.001035, test:0.001348
# Epoch[82/200] | loss train:0.003622, test:0.002686
# Epoch[83/200] | loss train:0.001968, test:0.001456
# Epoch[84/200] | loss train:0.001322, test:0.002323
# Epoch[85/200] | loss train:0.001560, test:0.001635
# Epoch[86/200] | loss train:0.001233, test:0.001149
# Epoch[87/200] | loss train:0.000976, test:0.001068
# Epoch[88/200] | loss train:0.000932, test:0.001002
# Epoch[89/200] | loss train:0.001190, test:0.001262
# Epoch[90/200] | loss train:0.001951, test:0.001516
# Epoch[91/200] | loss train:0.001136, test:0.001037
# Epoch[92/200] | loss train:0.000894, test:0.000994
# Epoch[93/200] | loss train:0.000900, test:0.000916
# Epoch[94/200] | loss train:0.000829, test:0.000939
# Epoch[95/200] | loss train:0.000801, test:0.000834
# Epoch[96/200] | loss train:0.000837, test:0.000929
# Epoch[97/200] | loss train:0.000866, test:0.001046
# Epoch[98/200] | loss train:0.001802, test:0.001189
# Epoch[99/200] | loss train:0.000897, test:0.000919
# Epoch[100/200] | loss train:0.000807, test:0.000892
# Epoch[101/200] | loss train:0.000776, test:0.000786
# Epoch[102/200] | loss train:0.000723, test:0.000807
# Epoch[103/200] | loss train:0.000777, test:0.000969
# Epoch[104/200] | loss train:0.000731, test:0.000816
# Epoch[105/200] | loss train:0.000700, test:0.000876
# Epoch[106/200] | loss train:0.000711, test:0.000821
# Epoch[107/200] | loss train:0.000743, test:0.000817
# Epoch[108/200] | loss train:0.000732, test:0.000814
# Epoch[109/200] | loss train:0.000779, test:0.001202
# Epoch[110/200] | loss train:0.001368, test:0.001425
# Epoch[111/200] | loss train:0.000861, test:0.000687
# Epoch[112/200] | loss train:0.000652, test:0.000729
# Epoch[113/200] | loss train:0.001501, test:0.002040
# Epoch[114/200] | loss train:0.000861, test:0.000760
# Epoch[115/200] | loss train:0.000614, test:0.000650
# Epoch[116/200] | loss train:0.000573, test:0.000615
# Epoch[117/200] | loss train:0.000598, test:0.000639
# Epoch[118/200] | loss train:0.000592, test:0.000580
# Epoch[119/200] | loss train:0.000529, test:0.000539
# Epoch[120/200] | loss train:0.000503, test:0.000539
# Epoch[121/200] | loss train:0.000501, test:0.000530
# Epoch[122/200] | loss train:0.000535, test:0.000575
# Epoch[123/200] | loss train:0.000478, test:0.000480
# Epoch[124/200] | loss train:0.000462, test:0.000490
# Epoch[125/200] | loss train:0.000497, test:0.000487
# Epoch[126/200] | loss train:0.000469, test:0.000465
# Epoch[127/200] | loss train:0.000459, test:0.000579
# Epoch[128/200] | loss train:0.000474, test:0.000519
# Epoch[129/200] | loss train:0.000467, test:0.000577
# Epoch[130/200] | loss train:0.000463, test:0.000630
# Epoch[131/200] | loss train:0.003631, test:0.003547
# Epoch[132/200] | loss train:0.003283, test:0.002254
# Epoch[133/200] | loss train:0.002488, test:0.001607
# Epoch[134/200] | loss train:0.001587, test:0.001247
# Epoch[135/200] | loss train:0.001414, test:0.001443
# Epoch[136/200] | loss train:0.001874, test:0.001332
# Epoch[137/200] | loss train:0.001249, test:0.001225
# Epoch[138/200] | loss train:0.001293, test:0.001182
# Epoch[139/200] | loss train:0.001031, test:0.001266
# Epoch[140/200] | loss train:0.001148, test:0.001465
# Epoch[141/200] | loss train:0.001007, test:0.001134
# Epoch[142/200] | loss train:0.000764, test:0.000768
# Epoch[143/200] | loss train:0.000703, test:0.000785
# Epoch[144/200] | loss train:0.000708, test:0.000660
# Epoch[145/200] | loss train:0.000599, test:0.000629
# Epoch[146/200] | loss train:0.000549, test:0.000580
# Epoch[147/200] | loss train:0.000569, test:0.000553
# Epoch[148/200] | loss train:0.000525, test:0.000538
# Epoch[149/200] | loss train:0.000512, test:0.000538
# Epoch[150/200] | loss train:0.000545, test:0.000547
# Epoch[151/200] | loss train:0.000607, test:0.000693
# Epoch[152/200] | loss train:0.000757, test:0.000596
# Epoch[153/200] | loss train:0.000518, test:0.000585
# Epoch[154/200] | loss train:0.000477, test:0.000472
# Epoch[155/200] | loss train:0.000436, test:0.000458
# Epoch[156/200] | loss train:0.000421, test:0.000452
# Epoch[157/200] | loss train:0.000433, test:0.000455
# Epoch[158/200] | loss train:0.000420, test:0.000468
# Epoch[159/200] | loss train:0.000436, test:0.000509
# Epoch[160/200] | loss train:0.000425, test:0.000465
# Epoch[161/200] | loss train:0.001151, test:0.002590
# Epoch[162/200] | loss train:0.002573, test:0.002351
# Epoch[163/200] | loss train:0.001868, test:0.001224
# Epoch[164/200] | loss train:0.000940, test:0.000951
# Epoch[165/200] | loss train:0.000618, test:0.000617
# Epoch[166/200] | loss train:0.000512, test:0.000506
# Epoch[167/200] | loss train:0.000457, test:0.000481
# Epoch[168/200] | loss train:0.000444, test:0.000443
# Epoch[169/200] | loss train:0.000427, test:0.000442
# Epoch[170/200] | loss train:0.000401, test:0.000420
# Epoch[171/200] | loss train:0.000382, test:0.000400
# Epoch[172/200] | loss train:0.000377, test:0.000389
# Epoch[173/200] | loss train:0.000370, test:0.000386
# Epoch[174/200] | loss train:0.000358, test:0.000387
# Epoch[175/200] | loss train:0.000369, test:0.000401
# Epoch[176/200] | loss train:0.000342, test:0.000352
# Epoch[177/200] | loss train:0.000345, test:0.000336
# Epoch[178/200] | loss train:0.000339, test:0.000343
# Epoch[179/200] | loss train:0.000334, test:0.000352
# Epoch[180/200] | loss train:0.000341, test:0.000466
# Epoch[181/200] | loss train:0.000346, test:0.000335
# Epoch[182/200] | loss train:0.000332, test:0.000361
# Epoch[183/200] | loss train:0.000331, test:0.000386
# Epoch[184/200] | loss train:0.000343, test:0.000332
# Epoch[185/200] | loss train:0.000330, test:0.000323
# Epoch[186/200] | loss train:0.000331, test:0.000420
# Epoch[187/200] | loss train:0.000334, test:0.000332
# Epoch[188/200] | loss train:0.000312, test:0.000303
# Epoch[189/200] | loss train:0.000332, test:0.000327
# Epoch[190/200] | loss train:0.000325, test:0.000402
# Epoch[191/200] | loss train:0.000365, test:0.000366
# Epoch[192/200] | loss train:0.000320, test:0.000336
# Epoch[193/200] | loss train:0.000324, test:0.000372
# Epoch[194/200] | loss train:0.000307, test:0.000354
# Epoch[195/200] | loss train:0.000297, test:0.000327
# Epoch[196/200] | loss train:0.000293, test:0.000286
# Epoch[197/200] | loss train:0.000297, test:0.000298
# Epoch[198/200] | loss train:0.000300, test:0.000295
# Epoch[199/200] | loss train:0.000287, test:0.000313
# Epoch[200/200] | loss train:0.000285, test:0.000286

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(test_losses, label='Test loss')
plt.xlabel('Epochs', color='white')
plt.xticks(color='white')  # Change tick color to 'green'
plt.ylabel('Y-axis', color='white')
plt.ylabel('Loss')
plt.yticks(color='white')  # Change tick color to 'green'
plt.title("Loss_train_test(1,50,5,120)", color='white')
plt.legend()
plt.savefig('gru_loss(1,50,5,120).png', dpi=300, bbox_inches='tight', transparent=True);
plt.show()

# %%
model_gru = GRU(1, 50, 3, 120)
model_gru.to(device)
# Out:
# GRU(
#   (gru): GRU(1, 50, num_layers=3, batch_first=True)
#   (fc): Linear(in_features=50, out_features=120, bias=True)
# )

# %%
y_predict = torch.tensor(y[-60:], dtype=torch.float32).unsqueeze(0)
y_predict = model_lstm(y_predict.to(device))
y_predict = y_predict.to('cpu').detach().numpy().reshape(-1, 1)
y_predict = scaler.inverse_transform(y_predict)

# %%
data_pytorch = creat_dataframe(df['Close'], y_predict)

# %%
data_pytorch[data_pytorch['Date'] > '2024-03-01'].plot(x='Date', y = 'Price', lw=2)
plt.xlabel("Date", color='white')
plt.xticks(color='white')  # Change tick color to 'green'
plt.ylabel('Loss', color = 'white')
plt.yticks(color='white')  # Change tick color to 'green'
plt.title("Giá BTC từ 4-8/2024(1,50,5,120)", color='white')
plt.ylabel('USD')
plt.savefig('gru(1,50,5,120).png', dpi=300, bbox_inches='tight', transparent=True)

# %%
data_pytorch.plot(x='Date', y='Price')
plt.xlabel("Date", color='white')
plt.xticks(color='white')  # Change tick color to 'green'
plt.ylabel('Loss', color = 'white')
plt.yticks(color='white')  # Change tick color to 'green'
plt.title("Giá BTC từ 4-8/2024(1,50,5,120)", color='white')
plt.ylabel('USD')
plt.savefig('all_gru(1,50,5,120).png', dpi=300, bbox_inches='tight', transparent=True);
